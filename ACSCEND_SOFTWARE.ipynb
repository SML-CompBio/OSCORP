# %%
# !pip install mygene

# %%
import pandas as pd
import numpy as np
from scipy import stats
import pickle
from sklearn.svm import NuSVR
from sklearn.model_selection import GridSearchCV
import mygene
import time

# %% [markdown]
# The input file raw_data_2samples.txt with gene expression data (CPM) is required to be in the .txt file format, with the first column containing Gene Symbols formatted in Hugo, Entrez, or Ensembl format.
#
# If the Gene Symbol is not in the Ensmbl Format, the active internet connection is required for the conversion of the gene format to Ensembl.
#
# The following columns should contain the patient sample.
#
# The output file is a dataframe containg the stem cell class, Intra-Tumor Heterogenity (ITH), and frequency of immune cells, stem cells, and tumor cells.

# %%
def read_rna(file_path):

    rna = pd.read_csv(file_path, index_col=(0), sep='\t')
    rna = rna.iloc[:, :2]
    rna.index = rna.index.astype(str)
    rna = rna.loc[~rna.index.duplicated(keep='first')]
    rna.dropna(axis=0, how='any', inplace=True)
    rna.dropna(axis=1, how='any', inplace=True)
    print('Sample file loaded')
    return rna

# %%
def read_sig(file_path):

    sig = pd.read_csv(file_path, index_col=(0))
    return sig

# %%
def cibersort(rna, sig, n_core=1):

    gridsearch = GridSearchCV(NuSVR(C=1.0, kernel='linear', max_iter=-1, shrinking=True),
                              cv=5, param_grid={"nu": [0.25, 0.5, 0.75]}, n_jobs= n_core,
                              scoring='neg_mean_squared_error', refit=True)
    gridsearch.fit(sig, rna)
    nu = gridsearch.best_params_['nu']

    clf = NuSVR(nu=nu, C=1.0, kernel='linear', max_iter=-1, shrinking=True, tol=1e-3)
    clf.fit(sig, rna)

    weights = np.array(clf.coef_)[0]
    weights[weights<0] = 0
    weights = weights / np.sum(weights)

    return weights

# %%
def cibersort_pipeline(rna, sig, n_core=1):

    common = list(set(rna.index) & set(sig.index))
    rna = rna[rna.index.isin(common)].sort_index()
    sig = sig[sig.index.isin(common)].sort_index()
    rna = stats.zscore(rna, axis=0, ddof=1)
    sig = stats.zscore(sig, axis=0, ddof=1)
    freq = pd.DataFrame(columns = rna.columns)
    freq['sample'] = sig.columns
    for patient in rna.columns:
        weights = cibersort(rna[patient], sig)
        freq[patient] = weights
    freq = freq.T
    print('Deconvolution done!')
    return freq

# %% [markdown]
# Citation for inter-tumour heterogenity

# %%
def ith(cancer):

    cancer = np.log2(cancer + 1)
    means = cancer.mean(axis=1).values
    # cancer = np.array(cancer)
    # z = (cancer - means[:, np.newaxis])**2
    z = (cancer.values - means[:, None])**2
    
    score = (np.sqrt(np.sum(z, axis=0) / (cancer.shape[0] - 1))).tolist()
    print('Inter-Sample Heterogenity calculated!')
    return score

# %%
def classification(model_path, rna):

    model_name = model_path
    model = pickle.load(open(model_name, 'rb'))
    feat = model.feature_names_in_
    rna = rna.loc[~rna.index.duplicated(keep='first')]
    rna = rna.T
    rna = rna.reindex(columns = feat, fill_value = 0).fillna(0)
    predictions=model.predict(rna)
    map_dict = {0: 'hESC', 1 : 'hMSC', 2 : 'hUSC', 3 : 'iPSC'}
    pred = [map_dict[element] for element in predictions]
    print('Classification Done!')
    return pred

# %%
def converter(rna, gene = None):

    mg = mygene.MyGeneInfo()
    if gene == 'Entrez':
        out = mg.querymany(rna.index, scopes='entrezgene', fields='ensembl.gene', species='human',
                           verbose = False, returnall=True, size=1)
        ensembl_list = []
        for i in out['out']:
            try:
                ensembl_list.append(i['ensembl']['gene'])
            except:
                ensembl_list.append('None')
        rna = rna.set_index(pd.Index(ensembl_list))
        rna = rna[rna.index != ('None')]
    elif gene == 'Hugo':
        out = mg.querymany(rna.index, scopes='symbol', fields='ensembl.gene', species='human',
                           verbose=False, returnall=True, size=1)
        ensembl_list = []
        for i in out["out"]:
            try:
                ensembl_list.append(i['ensembl']['gene'])
            except:
                ensembl_list.append('None')
        rna = rna.set_index(pd.Index(ensembl_list))
        rna = rna[rna.index != ('None')]
    elif gene == 'Ensembl':
        rna = rna
    else:
        rna = print('Please provide appropriate gene format name')
    return rna

# %%
def final_pipe(rna_path, sig_path, model_path, gene=None):
    rna = read_rna(rna_path)
    sig = read_sig(sig_path)
    rna = converter(rna, gene=gene)
    decon = cibersort_pipeline(rna, sig)
    ith1 = ith(rna)
    classification1 = classification(model_path, rna)
    data = decon
    data.columns = data.iloc[-1]
    data = data.iloc[:-1]
    data.insert(0, 'Class', classification1)
    data.insert(1, 'ITH', ith1)
    return data

# %%
tcga_rna_data_file = 'Data/Software_Data/raw_data_2samples.txt'
sig_mat_data_file = 'Data/Software_Data/sigmat.csv'
save_model_file = 'Data/Software_Data/svm_stemformatics.sav'

# %%
'''
input: bulk RNA-Seq data,
        signature matrix,
        model,
        gene tyep: HUGO/ENSEMBLE/ENTREZ

output: stem cell class, Inter tumor heterogenity score (ITH), Deconvolution for immune cells, stem cells, tumor cells)
'''

begin = time.time()
data = final_pipe(tcga_rna_data_file, sig_mat_data_file, save_model_file, gene='Hugo')
end = time.time()
# Out:
# Sample file loaded
# Deconvolution done!
# Inter-Sample Heterogenity calculated!
# Classification Done!
# /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LinearSVC from version 1.2.1 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
data
# Out:
# sample     Class       ITH T cells CD8 Monocytes T cells CD4 NKT cells  \
# Patient-01  iPSC  0.917701         0.0   0.00165         0.0  0.017577
# Patient-02  iPSC  0.917701         0.0  0.006792         0.0  0.020226
#
# sample     B cells  NK cells      stem      PRAD  ... KIRC        OV  \
# Patient-01     0.0  0.001835  0.025276       0.0  ...  0.0  0.054817
# Patient-02     0.0       0.0  0.055024  0.006136  ...  0.0       0.0
#
# sample          LAML       GBM      CESC      CHOL      LIHC      BRCA   MB  \
# Patient-01  0.006989  0.006177  0.171029   0.03782       0.0       0.0  0.0
# Patient-02  0.002065  0.025703  0.220003  0.024202  0.000905  0.000846  0.0
#
# sample          HNSC
# Patient-01  0.159198
# Patient-02  0.186045
#
# [2 rows x 30 columns]

# %%
print("Time taken to run the main function: ", end - begin)
